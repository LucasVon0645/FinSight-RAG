# %% [markdown]
# ## Import Chat LLM config

# %%
from importlib import resources as impresources
import finsight_rag.config as config
from finsight_rag.utils import load_yaml

chat_config_path = (impresources.files(config) / "chat_llm_config.yaml")
chat_config = load_yaml(chat_config_path)
print("Available chat LLM configurations:")
print(list(chat_config.keys()))
# Out:
# Available chat LLM configurations:
# ['model_id', 'temperature', 'max_new_tokens']

# %%
gen_model = chat_config["model_id"]
temperature = chat_config["temperature"]
max_new_tokens = chat_config["max_new_tokens"]

print(f"Using generation model: {gen_model}")
print(f"Temperature: {temperature}")
print(f"Max new tokens: {max_new_tokens}")
# Out:
# Using generation model: gemini-2.5-flash
# Temperature: 0.0
# Max new tokens: 200

# %%
from finsight_rag.llms.llm_service import build_gemini_chat_llm

gemini_chat_llm = build_gemini_chat_llm(
    model_id='gemini-2.5-flash',
    temperature=temperature,
    max_new_tokens=max_new_tokens,
)
# Out:
# 2026-09-06 20:32:09 | INFO     | finsight_rag.logging_config:configure_logging:44 - Logging configured level=INFO file=C:\Users\lucas\projects\FinSight-RAG\logs\finsight.log

# %%
gemini_chat_llm
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash', temperature=0.0, max_output_tokens=200, client=<google.genai.client.Client object at 0x0000020A0E9FE440>, default_metadata=(), model_kwargs={})

# %%
gemini_chat_llm.invoke("What is the capital of France?")
# Out:
# AIMessage(content='The capital of France is **Paris**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a07911-9504-7040-ad06-a9c0a77168ed-0', usage_metadata={'input_tokens': 8, 'output_tokens': 33, 'total_tokens': 41, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 25}})

# %%
from finsight_rag.llms.llm_service import build_hf_remote_chat_llm

hf_chat_llm = build_hf_remote_chat_llm(
    model_id="meta-llama/Llama-3.2-3B-Instruct",
    temperature=temperature,
    max_new_tokens=max_new_tokens,
)

# %%
hf_chat_llm.invoke("What is the capital of France?")
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 42, 'total_tokens': 49}, 'model_name': 'meta-llama/Llama-3.2-3B-Instruct', 'system_fingerprint': 'fp1-rss-h1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a078e6-d51a-7150-97c9-4207bf916d65-0', usage_metadata={'input_tokens': 42, 'output_tokens': 7, 'total_tokens': 49})
